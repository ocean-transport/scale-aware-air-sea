# %% [markdown]
# # Problems accessing dask dashboard from Local Cluster
#
# Posted [here](https://discourse.pangeo.io/t/access-dashboard-for-localcluster-on-pangeo-deployments/2171)

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# /srv/conda/envs/notebook/lib/python3.8/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34801 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:36435' processes=2 threads=2, memory=4.00 GiB>

# %% [markdown]
# That link is useless from the outside...
